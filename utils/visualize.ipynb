# %%
import matplotlib.pyplot as plt
from helper import get_data

# Add the rl directory to the system path
df = get_data("GOOG")
print(df.head())
# Out:
#                 Open      High       Low  Adj Close    Volume    Return  \
# Date
# 2014-01-02 -1.098487 -1.103124 -1.096708  -1.100296  2.056885 -0.006773
# 2014-01-03 -1.098794 -1.103665 -1.098956  -1.105714  1.730473 -0.007295
# 2014-01-06 -1.100123 -1.102392 -1.097937  -1.097493  1.946956  0.011149
# 2014-01-07 -1.092117 -1.088651 -1.088000  -1.083120  3.599697  0.019278
# 2014-01-08 -1.078094 -1.083617 -1.079813  -1.081539  2.945394  0.002081
#
#                  SMA       EMA      MACD      BIAS       VVR
# Date
# 2014-01-02 -1.117452 -1.103371 -0.269658  0.342484 -0.691577
# 2014-01-03 -1.116178 -1.102535 -0.268586  0.092295 -0.276282
# 2014-01-06 -1.114938 -1.102803 -0.270556  0.352116  0.262694
# 2014-01-07 -1.112818 -1.101592 -0.268209  0.806140  1.477304
# 2014-01-08 -1.109324 -1.098113 -0.259004  0.731734 -0.031192

# %%
fig, axs = plt.subplots(len(df.columns), 1, figsize=(14, 40))

# Plot each element in a separate subplot
for i, column in enumerate(df.columns):
    axs[i].plot(df.index, df[column])
    axs[i].set_title(column)
    axs[i].set_xlabel('Date')
    axs[i].set_ylabel('Value')

plt.tight_layout()
plt.show()
