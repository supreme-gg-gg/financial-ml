# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

import matplotlib.pyplot as plt
from utils import get_data

# Add the rl directory to the system path
df = get_data("GOOG.csv")
print(df.head())
# Out:
#                 Open      High       Low     Close  Adj Close    Volume  \
# Date
# 2014-01-02 -1.098487 -1.103124 -1.096708 -1.100296  -1.100296  2.056885
# 2014-01-03 -1.098794 -1.103665 -1.098956 -1.105714  -1.105714  1.730473
# 2014-01-06 -1.100123 -1.102392 -1.097937 -1.097493  -1.097493  1.946956
# 2014-01-07 -1.092117 -1.088651 -1.088000 -1.083120  -1.083120  3.599697
# 2014-01-08 -1.078094 -1.083617 -1.079813 -1.081539  -1.081539  2.945394
#
#               Return       SMA       EMA      MACD      BIAS       VVR
# Date
# 2014-01-02 -0.006773 -1.117452 -1.103371 -0.269658  0.342484 -0.659494
# 2014-01-03 -0.007295 -1.116178 -1.102535 -0.268586  0.092295 -0.237748
# 2014-01-06  0.011149 -1.114938 -1.102803 -0.270556  0.352116  0.119090
# 2014-01-07  0.019278 -1.112818 -1.101592 -0.268209  0.806140  1.364496
# 2014-01-08  0.002081 -1.109324 -1.098113 -0.259004  0.731734  0.024513

# %%
fig, axs = plt.subplots(len(df.columns), 1, figsize=(14, 40))

# Plot each element in a separate subplot
for i, column in enumerate(df.columns):
    axs[i].plot(df.index, df[column])
    axs[i].set_title(column)
    axs[i].set_xlabel('Date')
    axs[i].set_ylabel('Value')

plt.tight_layout()
plt.show()
